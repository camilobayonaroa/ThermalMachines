# %% [markdown]
# # Máquinas Térmicas - Lección 6
# ## Tecnología para la Combustión
#
# **Autor:** Camilo Bayona
# **Fecha:** 13/08/2025

# %% [markdown]
# ### Objetivos de aprendizaje
#
# Al finalizar esta lección, el/la estudiante será capaz de:
#
# 1. Describir las principales características físicas y químicas de los combustibles sólidos, líquidos y gaseosos empleados en ingeniería térmica.
# 2. Clasificar los combustibles según su origen, composición elemental, contenido de humedad y poder calorífico.
# 3. Explicar el funcionamiento básico de las tecnologías de combustión más comunes: hornos, calderas, motores de combustión interna, turbinas de gas y quemadores industriales.
# 4. Relacionar la elección del combustible y la tecnología de combustión con parámetros de eficiencia, control de emisiones y requisitos operativos.
# 5. Comparar las ventajas y limitaciones de diferentes tecnologías de combustión en aplicaciones industriales y de generación de energía.
# 6. Aplicar conceptos de combustión para seleccionar el combustible y la tecnología más adecuados en escenarios prácticos.

# %% [markdown]
# ##1. Introducción
#
# La combustión ha sido una parte integral de la tecnología humana desde el descubrimiento del fuego. Los primeros humanos utilizaban la combustión para calentar sus hogares, cocinar alimentos y producir luz.
#
# ![Campfire](https://upload.wikimedia.org/wikipedia/commons/b/b7/Campfire_4213.jpg)
#
# Con el tiempo, la tecnología de la combustión se ha desarrollado y refinado para una variedad de aplicaciones, desde la producción de energía en centrales eléctricas hasta la propulsión de vehículos y aeronaves. A lo largo de la historia, la tecnología de la combustión ha evolucionado para ser más eficiente y menos dañina para el medio ambiente.
#
# ![Boiler](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Jocko%27s_Steakhouse_-_September_2023_-_Sarah_Stierch_03.jpg/640px-Jocko%27s_Steakhouse_-_September_2023_-_Sarah_Stierch_03.jpg)

# %% [markdown]
# ##2. Combustibles sólidos
#
# Los combustibles sólidos son aquellos que están en estado sólido a temperatura ambiente.
#
# ![output(2).png](data:image/png;base64,...)
#
#
# *   Biomasa (no fósil): Residuos agrícolas, leña, pellets, etc. Se considera renovable si la tasa de consumo no supera la tasa de regeneración.
# *   Carbones procesados: Briquetas de carbón, coque (a partir del carbón mineral), etc.
#
#
# ### 2.1 Madera
#
# La madera es un combustible sólido de origen vegetal. Se utiliza principalmente para la calefacción y la cocción de alimentos. La madera produce una cantidad moderada de calor y produce humo cuando se quema.
#
# ![wood](https://upload.wikimedia.org/wikipedia/commons/9/91/Holzpellets.jpg)
#
# ### Tabla – Comparación del poder calorífico de la madera en bases seca y húmeda
#
# | Contenido de humedad (%) | Base seca (%) | Poder calorífico superior (kJ/kg) - Base seca | Poder calorífico superior (kJ/kg) - Base húmeda |
# |--------------------------|---------------|----------------------------------------------|------------------------------------------------|
# | 0                        | 0.0           | 22300                                        | 22300                                          |
# | 10                       | 9.1           | 20100                                        | 20100                                          |
# | 25                       | 20.0          | 17900                                        | 18900                                          |
# | 50                       | 33.3          | 14800                                        | 17900                                          |
# | 100                      | 50.0          | 11200                                        | 14800                                          |
# | 200                      | 66.7          | 7600                                         | 13400                                          |
#
#
# ### 2.2 Carbón Mineral
#
# El carbón es un combustible sólido de origen vegetal. Se forma a partir de la descomposición de la materia vegetal en condiciones de alta presión y temperatura. El carbón se clasifica en diferentes tipos según su contenido de carbono: turba, lignito, sub-bituminoso, bituminoso y antracita.
#
# a. Turba:
#
# ![Peat](https://upload.wikimedia.org/wikipedia/commons/7/7d/Peat_%2849302157252%29.jpg)
#
# b. Lignito
#
# ![Lignite](https://upload.wikimedia.org/wikipedia/commons/8/85/Pliocene_Lignite_Coal_Serbia.jpg)
#
# c. Sub-bituminoso
#
# ![Bituminous](https://upload.wikimedia.org/wikipedia/commons/2/20/Coal_bituminous.jpg)
#
# d. Bituminoso:
#
# ![Bituminous](https://upload.wikimedia.org/wikipedia/commons/2/2e/Handvoll_Gold.jpg)
#
# e. Antracita:
#
# ![Anthracite](https://upload.wikimedia.org/wikipedia/commons/5/59/Anthracite_Coal_01_10x_%2838960276634%29.jpg)
#
# ![Rankin](https://upload.wikimedia.org/wikipedia/commons/2/21/Coal_Rank_USGS.png)

# %%
# Instalar Graphviz (si es necesario) en Colab/Jupyter:
# !apt-get update -qq
# !apt-get install graphviz -y
# !pip install graphviz

from graphviz import Digraph

dot = Digraph(comment='Calidades del Carbón', format='png')
dot.attr(rankdir='TB', size='8,10')
dot.node_attr.update(shape='record', fontsize='10')

# Cada nodo se define como un "record" con tres columnas:
dot.node('Lignito', '{Lignito (Baja calidad) | Capacidad Calorífica: ≈15 MJ/kg | Aplicación: Generación eléctrica de baja demanda}')
dot.node('Hulla', '{Hulla (Sub-bituminoso) | Capacidad Calorífica: ≈18 MJ/kg | Aplicación: Calefacción y generación eléctrica}')
dot.node('Bituminoso', '{Bituminoso (Calidad intermedia) | Capacidad Calorífica: ≈24 MJ/kg | Aplicación: Industria y generación eléctrica}')
dot.node('Antracita', '{Antracita (Alta pureza) | Capacidad Calorífica: ≈30 MJ/kg | Aplicación: Siderurgia y calefacción de alto rendimiento}')
dot.node('Diamante', '{Diamante (Extra puro) | Capacidad Calorífica: ≈35 MJ/kg | Aplicación: Industria especializada y alta tecnología}')

# Conectar verticalmente (de forma invisible) para ordenar las filas:
dot.edge('Lignito', 'Hulla', style='invis')
dot.edge('Hulla', 'Bituminoso', style='invis')
dot.edge('Bituminoso', 'Antracita', style='invis')
dot.edge('Antracita', 'Diamante', style='invis')

dot.render('calidades_carbon_tabla', view=True)
dot

# %% [markdown]
# ### Tabla – Clasificación de carbones por rango (ASTM D388)
#
# | Clase               | Grupo                   | Carbono fijo % (seco, sin minerales) | Materia volátil % | Poder calorífico (kJ/kg) |
# |---------------------|-------------------------|---------------------------------------|-------------------|--------------------------|
# | **I. Antracitas**   | 1. Meta-antracitas       | 98                                    | 2                 | —                        |
# |                     | 2. Antracitas            | 92–98                                 | 2–8               | —                        |
# |                     | 3. Semi-Antracitas       | 86–92                                 | 8–14              | —                        |
# | **II. Bituminosos** | 1. Bajos volátiles       | 78–86                                 | 14–22             | —                        |
# |                     | 2. Volátiles medios     | 69–78                                 | 22–31             | —                        |
# |                     | 3. Volátiles altos, A    | <69                                   | >31               | 32500                    |
# |                     | 4. Volátiles altos, B    | —                                     | —                 | 30200–32500              |
# |                     | 5. Volátiles altos, C    | —                                     | —                 | 26700–30200              |
# | **III. Sub-bituminosos** | 1. Sub-bituminosos, A | —                                     | —                 | 24400–26700              |
# |                     | 2. Sub-bituminosos, B    | —                                     | —                 | 22100–24400              |
# |                     | 1. Sub-bituminosos, C    | —                                     | —                 | 19300–22100              |
# | **IV. Lignitos**    | 1. Lignitos, A           | —                                     | —                 | 14600–19300              |
# |                     | 2. Lignitos, B           | —                                     | —                 | 14600                    |

# %% [markdown]
# ### 3. Sistemas de Combustión de Sólidos
#
# | Año     | Desarrollador        | Aplicación                                                    |
# |---------|----------------------|---------------------------------------------------------------|
# | 200 a.C.| Hero                 | Aelopile como fuente de energía;             |
# | 1600    | Branca               | Primera turbina de vapor                                     |
# | 1680    | Denis Papin          | Digestor de vapor para procesamiento de alimentos; uso de válvula de seguridad |
# | 1720    | Haycock              | Caldera tipo shell hecha de placas de cobre                |
# | 1730    | James Allen          | Horno interno; uso de fuelle para el aire de combustión      |
# | 1766    | William Blakey       | Patente de agua dentro de tubo y fuego afuera               |
# | 1803    | John Stevens         | Diseño pseudo de tubos de agua utilizado en un barco de vapor |
# | 1804    | Richard Trevithick   | Primera caldera de alta presión con carcasa cilíndrica de hierro fundido |
# | 1822    | Jacob Perkins        | Caldera de flujo continuo usando hierro fundido (fuego)     |
# | 1856    | Stephen Wilcox       | Caldera de tubos inclinados con recintos enfriados por agua  |
# | 1880    | Allan Stirling       | Tubos curvados conectando tambores                          |
# | 1881    | Brush Electric Light Co. | Llegada de la era actual del sistema de suministro de energía eléctrica |
# | 1920s   |   -     | Caldera de carbón pulverizado; se elimina la limitación de tamaño |
# | 1957    | Ohio Power Co.                 | Caldera supercrítica                                         |
# | 1970s   | -                    | Introducción de calderas de lecho fluidizado burbujeante     |
# | 1980s   | -                    | Introducción de calderas de lecho fluidizado circulante-                                                           |
#
# *P. Basu et al,* (2000).

# %% [markdown]
# ### 3.1 Parrilla fija (lecho de ignición)

# %% [markdown]
# Las calderas con parrillas fijas **no son adecuados** para la **gasificación de combustibles ni para la quema de carbón**. Pero estas **son eficientes**  para la **quema de madera y biocombustibles** como bagazo ya que se pueden distribuir en la parrilla fácilmente con la ayuda de esparcidores.
#
# \
# Suelen diseñarse con una inclinacion nominal de 5° a 7°.
#
# \
# Las placas de rejilla de acero al cromo de alta temperatura se sujetan al piso del horno para crear una superficie plana y estacionaria de la parrilla. Las placas en la parte inferior se maquinan y se ajustan a la forma de los tubos para asegurar un buen contacto metal-metal. De esta manera, las placas se mantienen relativamente frías a menos de 450°C, incluso mientras la combustión tiene lugar por encima. A intervalos regulares, se insertan placas con boquillas de vapor en la parrilla. Esto ayuda a soplar periódicamente las cenizas hacia el extremo de descarga con la ayuda del vapor.

# %% [markdown]
# __Proceso de
# combustión en parrillas
# fijas.__
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Barrera, J. et al.(2019)

# %% [markdown]
# __Disposición de las placas en las parrillas fijas__
#
# ![image.png](data:image/png;base64,...)
#
#
# Rayaprolu, K. (2013)

# %% [markdown]
# ### 3.2 Parrilla viajera

# %% [markdown]
# Estas parrillas fueron precursoras y populares hasta la década de 1960, cuando los carbones eran de buena calidad y los requisitos de la industria de procesos eran modestos. Aunque **son adecuados para carbones y lignitos de buena calidad** y especialmente buenos para combustibles abrasivos como el **coque de coquización**, **no son muy adecuados** para **biocombustibles** debido a la forma en que el combustible debe ser admitido.
#
#
# En este tipo de hogares casi un 85% de la combustión que tiene lugar en la superficie de la parrilla, muestra una combustión lenta y tasas modestas de quema de carbón. El rendimiento disminuye bruscamente cuando las cenizas y los finos en el carbón aumentan por encima de los límites. Los límites de tamaño del carbón son importantes.
#
# Arches refractarios especialmente diseñados en la parte delantera y trasera ayudan a reemitir el calor y dirigir los gases calientes del humo hacia la cama de combustible para ayudar en la ignición.
#
# __Aspectos del diseño__
# - Los carbones deben ser moderadamente coquizables o aglomerantes y tener las siguientes características:
#   - Tamaño máximo de 32 mm y finos de $<$35% a través de 3 mm (lo que corresponde a $<$ 15% a través de 1 mm).
#   - Cenizas tal como se queman limitadas al 25%.
#   - Humedad total tal como se queman limitada al 18%.
#   - Volátiles mínimos secos sin cenizas (daf) del 25%.
# - Casi un 85% de las cenizas del carbón se retienen en la parrilla como cenizas gruesas, mientras que un 15% sale como cenizas volantes. Las cenizas volantes son relativamente abrasivas.
# - Las tasas de combustión son de 160 y 185 kg/m2/h (33 y 38 lb/ft2/h) para ajustes con arcos y sin arcos en el horno.
# - La tasa de descarga de cenizas debe ser $<$ 350 kg/m/h (230 lb/ft/h) a lo ancho del estoker para mantener la pérdida de combustión incompleta a una cifra razonable.
# - La presión del aire debajo de la parrilla es de aproximadamente 55 mm de columna de agua (2 ¼ pulgadas de columna de agua) debido a que la capa de combustible es gruesa.

# %% [markdown]
# __Parrilla viajera__
#
#
# ![image.png](data:image/png;base64,...)
#
# Rayaprolu, K. (2013)

# %% [markdown]
# __Proyección de combustible__

# %% [markdown]
# El hogar de proyección utiliza distribuidores de combustible para lanzar el combustible de manera uniforme sobre parrillas viajeras o de otro tipo.
#
# El hogar de proyección es una verdadera combinación de dos en uno, ya que toma parte de la combustión en el horno y parte en la parrilla, liberando casi el doble de calor para la misma área de parrilla. La caldera resultante es más compacta.
#
# - Como la combustión tiene lugar en suspensión en el horno en un porcentaje del 40 al 60% para biocombustibles y del 35 al 50% para carbones, la capa de combustible en la parrilla es delgada (50-80 mm) y la combustión es más vigorosa.
#
# - La respuesta a la carga es mucho más rápida que en la combustión masiva.
#
# - Normalmente es posible una reducción de carga continua de 3:1.
# - Por lo general, no se requieren arcos en el horno. Sin embargo, se proporciona un flujo de aire secundario (HP SA) de 600-750 mm de columna de agua, que representa del 20% al 30% del aire total, para ayudar a la combustión en suspensión y proporcionar una agitación completa.
# - Para biocombustibles que son muy livianos y propensos a la alta emisión, parte del flujo de aire secundario se desvía como aire secundario superior para formar una cortina de aire en la parte superior del horno.
# - En la distribución asimétrica de carbón, las cenizas se transportan generalmente hacia el lado frontal. En la quema de carbón, el hogar de proyección lanza las piezas más grandes hacia el lado trasero y las más pequeñas hacia el frente. El recorrido hacia adelante le da a las piezas más grandes más tiempo para la combustión.
# - En la combustión en suspensión, la cantidad de cenizas volantes transportadas es bastante alta, alrededor del 20-40%.

# %% [markdown]
# __Hogar de proyección con parrilla viajera__
#
# ![image.png](data:image/png;base64,...)
#
#
# Rayaprolu, K. (2009)

# %% [markdown]
# ### 3.3 Hogar alimentado por debajo

# %% [markdown]
# Este tipo de hogares son alimentados tanto con aire como con carbón desde la parte inferior de la parrilla, como se muestra en la Figura. La combustión avanza de abajo hacia arriba y las cenizas se elevan hacia la parte superior y finalmente se descargan por los lados. Las capacidades de estas calderas son muy pequeñas. Han prácticamente desaparecido del mercado industrial, sobreviviendo solo en pequeñas áreas aquí y allá.

# %% [markdown]
# __Diagrama de un lecho alimentado por debajo__
#
# ![image.png](data:image/png;base64,...)
#
# Rayaprolu, K. (2013)

# %% [markdown]
# ### 3.4 Combustores de lecho fluidizado

# %% [markdown]
# ### Etapas de Fluidización
#
# **Lecho estático**: Cuando se fuerza el paso de aire a través de un lecho cerrado de sólidos esparcidos sobre una placa inferior, el aire fluye a través de los espacios vacíos del lecho sin perturbarlo. A medida que aumenta la cantidad de aire, la velocidad y la caída de presión (Δp) a través del lecho aumentan de manera más o menos lineal hasta que el lecho comienza a expandirse y levantarse. Esto se conoce como lecho estático.
#
# **Fluidización**: En algún punto, llamado punto de fluidización mínimo, el lecho comienza a levantarse de la placa inferior. Para un lecho de partículas de carbón de $<$10 mm, el punto de fluidización está a $\approx$ 1 m/s de velocidad del lecho. A este punto se le llama inicio de la fluidización.
#
# La **velocidad del lecho** es la velocidad del aire o gas que abandona el lecho, expresada en volumen de fluido por área del lecho.
#
# **Lecho burbujeante**: A medida que el flujo aumenta aún más, se forman burbujas de aire y la altura del lecho aumenta. Las partículas en el lecho comienzan a girar dentro del lecho expandido. El lecho es plano y se agita vigorosamente. A esto se le llama lecho burbujeante porque el proceso se asemeja al burbujeo del agua caliente.
#
# **Lecho circulante**: Con un mayor aumento del flujo de aire, el lecho se expande para llenar la cámara superior y forma una nube de partículas. La nube es densa en la parte inferior y menos densa en la parte superior, con algunas partículas que efectivamente salen de la cámara mientras la mayoría fluye hacia abajo a lo largo de las paredes de la cámara. Las partículas elutriadas pueden regresar al lecho para establecer una circulación de partículas del lecho. Esto ocurre a velocidades del lecho $\geq$4 m/s cuando el diámetro medio de las partículas se mantiene bajo en 0.5–1 mm, y se denomina lecho de circulación completa o lecho de fluidización rápida.
#
# **Lecho expandido o turbulento**: Esta es una etapa de la fluidización que se encuentra entre los lechos burbujeante y circulante.
#
# **Arrastre o transporte por arrastre**: A velocidades >~7 m/s, el fenómeno entra en un régimen de transporte cuando las partículas simplemente abandonan la cámara sin regresar al lecho a lo largo de las paredes, lo que marca el final del proceso de fluidización. Esto se denomina inicio del arrastre o flujo de transporte.

# %% [markdown]
# __Caida de presión en el lecho frente a la velocidad durante las etapas de  fluidización__
#
# ![image.png](data:image/png;base64,...)
#
# Rayaprolu, K. (2013)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.5 Combustores en hogar ciclónico

# %% [markdown]
# En un hogar ciclónico, la mezcla partículas finas y aire primario entra al horno a través de una tubería central, mientras que el aire secundario (SA) desde la caja de aire ingresa tangencialmente para dar un giro a los gases. El aire primario y el aire secundario están casi en ángulo recto entre sí para que las partículas de combustible se limpien de manera efectiva. Las llamas son cortas, densas y turbulentas. La formación de NOx (óxidos de nitrógeno) es alta, y los diseños modernos adoptan la división del SA para prolongar la combustión. Además, el reparto de aire alrededor de la zona principal de combustión produce una combustión escalonada, lo que resulta en menores niveles de NOx. Una caja de aire compartimentada con medición independiente del flujo de aire es una de las primeras formas de reducir el NOx.

# %% [markdown]
# __Caldera con un hogar ciclónico__
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Rayaprolu, K. (2013)

# %% [markdown]
# __Bibliografia__
#
# Basu, Prabir & Kefa, Cen & Jestin, Louis. (2000). Boilers and Burners : Design and Theory / P. Basu, C. Kefa, L. Jestin.. 10.1007/978-1-4612-1250-8.
#
# Baukal Jr., C.E. (Ed.). (2013). The John Zink Hamworthy Combustion Handbook: Volume 1 - Fundamentals (2nd ed.). CRC Press. https://doi.org/10.1201/b12975
#
# Rayaprolu, K. (2009). Boilers for Power and Process (1st ed.). CRC Press. https://doi.org/10.1201/EBK1420075366
#
# Rayaprolu, K. (2013). Boilers: A Practical Reference (1st ed.). CRC Press. https://doi.org/10.1201/b12977.

# %% [markdown]
# ##4. Combustibles líquidos
#
# Los combustibles líquidos son aquellos que están en estado líquido a temperatura ambiente. Ejemplos de combustibles líquidos son la gasolina y el diesel.
#
#
# ### Tabla  – Composición típica del petróleo
#
# | Componente | Contenido (%) |
# |------------|---------------|
# | Carbono    | 84 – 87       |
# | Hidrógeno  | 11 – 16       |
# | Oxígeno    | 0 – 7         |
# | Nitrógeno  | 0 – 7         |
# | Azufre     | 0 – 4         |
#
#
# ###4.1 Gasolina
#
# La gasolina es un combustible líquido que se obtiene de la destilación del petróleo. Se utiliza principalmente como combustible para motores de combustión interna.
#
# ![gasoil](https://upload.wikimedia.org/wikipedia/commons/3/39/Gasoline_in_mason_jar.jpg)
#
#
# ###4.2 Diesel
#
# El diesel es un combustible líquido que se obtiene de la destilación del petróleo. Se utiliza principalmente como combustible para motores diesel.
#
# ![diesel](https://upload.wikimedia.org/wikipedia/commons/f/f1/Bequer-B100-SOJA-SOYBEAM.jpg)
#
# ###4.3 Combustibles No Fósiles: Biocombustibles
#
#     Bioetanol: Se obtiene por fermentación de azúcares o almidones (maíz, caña de azúcar, etc.).
#
# ![propane](https://upload.wikimedia.org/wikipedia/commons/c/c6/Ethanol_burning_flame.png)
#
#
#     Biodiésel: Se produce a partir de aceites vegetales o grasas animales.
#
# ![propane](https://upload.wikimedia.org/wikipedia/commons/e/e9/Biodiesel.JPG)

# %% [markdown]
# ##5. Sistemas de Combustión de Líquidos
#
# ###5.1 Atomizador de tipo mecánico

# %% [markdown]
# El atomizador mecánico es uno en el que la presión del propio combustible atomiza el combustible. También se le llama atomizador de chorro a presión. Existen varios tipos de atomizadores mecánicos. El más ampliamente utilizado se muestra en la Figura. Hay tres partes principales del quemador:
#
# -Atomizador
#
# -Revolucionador (Swirler)
#
# -Distribuidor de flujo
#
# Estos están dispuestos a lo largo del eje del quemador. El aceite fluye primero a través de un conjunto de pequeños orificios del distribuidor de flujo, luego fluye a través de las ranuras tangenciales del revolucionador, que hacen que el aceite gire. Luego, el aceite entra en la cámara de remolino de la cuchilla atomizadora. Desde aquí, el aceite gira rápidamente en la cámara de remolino y sale a chorros desde la boquilla atomizadora, formando gotas. Dado que el diseño mecánico del paso del flujo hace que el aceite se atomice, a estos tipos de atomizadores se les llama atomizadores mecánicos.

# %% [markdown]
# __Diagramas de un atomizador mecanico tipico__
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
#
#
#
# P. Basu et al, (2000)

# %% [markdown]
# __Numero de orificios $n$__
# Debe estar entre 5 y 30 por atomizador. Un mayor número de orificios de diámetro pequeño solo se puede utilizar si el caudal de aceite es constante.
#
# __Diámetro de los orificios de aceite $d_1$__
# El aceite a presión $P_o$ entra al orificio de mezcla a través de los orificios de aceite. Para el número seleccionado de orificios, $n$, el diámetro del orificio, $d_2$, se puede calcular a partir del área total de sección transversal de los orificios de aceite, $F_1$. El caudal de aceite requerido, $G$, será proporcional a la raíz cuadrada de la caída de presión a través del orificio de aceite y su densidad.
#
# Las ecuaciones relevantes son las siguientes:
#
# Caudal de aceite, $G$:
# $$G = 3600  \mu  F_1\sqrt{ 2 \rho \cdot \Delta P} $$
#
# donde:
#
# $G$ = caudal de aceite del atomizador, kg/h
#
# $\mu$ = coeficiente de flujo. Por lo general, $\mu$ = 0.7
#
# $F1$ = área total de sección transversal de los orificios de aceite, m²
#
# $\rho$ = densidad del aceite, kg/m³
#
# $\Delta P$ = Diferencia de presión de aceite antes del atomatizador $P_0$ y en el punto de mescla $P_3$, Pa
#
# $\Delta P$ = $P_0 - P _3$
#
#
# #### Diámetro de los orificios de vapor o aire, $d_2$:
#
# El diámetro del orificio de vapor (o aire), d2, se basa en la tasa de consumo de vapor (o aire), m2, que debe estar en el rango de 0.015-0.02 kg de vapor (o aire) por kg de aceite para garantizar una adecuada calidad de atomización.
#
# De la mecánica de fluidos, notamos que la tasa de consumo de vapor (o aire) es proporcional a la raíz cuadrada de su presión en la entrada del atomizador. Por lo tanto, su consumo por orificio se puede calcular como:
#
# $$m_2 = 3600 \mu F_2 \psi \sqrt{P_2 \rho_s}$$
#
#
# donde:
#
# $\mu$ = coeficiente de flujo
#
# $F_2$ = área total de sección transversal de los orificios de vapor (o aire), m²
#
# $\psi$ = 2.09 para vapor sobrecalentado, 1.99 para vapor saturado, 2.14 para aire comprimido
#
# $P_2$ = presión absoluta del medio atomizador en la entrada del atomizador, Pa
#
# $\rho_s$ = densidad del vapor (o aire) en la entrada del atomizador, kg/m³
#
#
# Debido a la resistencia de los orificios de vapor (o aire), la presión en la cámara de mezcla $P_3$ será menor que antes de ingresar al orificio. Tomamos esta presión $P_3$ como una fracción de la presión aguas arriba, $P_2$. Entonces, podemos escribir:
#
# $$P_3 = \beta P_2$$
#
# donde $\beta$ es un coeficiente. Es aproximadamente 0.94 para una presión de aceite mayor que la presión de vapor.

# %% [markdown]
# Observamos que después de que el medio atomizado entra al orificio de mezcla desde el orificio de vapor, es perturbado por el aceite que fluye desde los orificios de aceite. Por lo tanto, es difícil conocer con precisión el coeficiente de flujo.
#
# También depende de la relación entre las áreas de los orificios de vapor, aceite y mezcla, así como de la velocidad de salida en los orificios de aceite.
#
# Para una primera aproximación, se puede tomar un valor a partir de la aproximación lineal de los datos experimentales que muestran su dependencia con la velocidad de salida del aceite .
#
# La relación entre el diámetro del orificio de vapor y el diámetro del orificio de aceite es una función de la tasa de flujo de vapor, que generalmente es constante para el atomizador de tipo Y. Podemos tomar la relación en el rango de ($d_2/d_1$ = 1.0-1.4) para una primera estimación.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Coeficiente de flujo, $\mu$, para el flujo de aceite a través de los orificios de aceite, trazado como función de las velocidades de salida de los orificios de aceite y diferentes relaciones de áreas de los orificios de aire/vapor ($F_1$), área de los orificios de aceite ($F_2$) y área de los orificios de mezcla ($F_3$) para el atomizador de tipo Y.

# %% [markdown]
# __Diámetro del Orificio de Mezcla, $d_3$__
#
# El área del orificio de mezcla está cerca de la suma de las áreas de sección transversal de los orificios de vapor y aceite. De esto se deduce que la relación entre el diámetro del orificio de mezcla y el diámetro del orificio de vapor (d3/d2) está en el rango de 1.4-1.8.
#
# __Longitud del Orificio de Mezcla__
#
# La longitud del orificio de mezcla ($L_3$) es la distancia entre la salida del orificio de aceite y la salida del orificio de mezcla. La distancia entre la salida de los orificios de aceite y la salida de los orificios de vapor (longitud, $l_1$,) también es un parámetro de diseño importante. Para permitir una buena mezcla de vapor y aceite y una transferencia completa de la energía del vapor al aceite, se pueden usar las siguientes relaciones:
#
# $$\frac{l_1}{d_3}=0.7$$
#
# $$\frac {l_3}{d_3} =4.0-5.0$$
#
# __Ángulo de Atomización, $\theta_a$__
#
# El rango preferido para este ángulo es entre 70 y 90 grados. El ángulo de atomización real puede ser aproximadamente 15-25 grados más grande que el valor de diseño de $\theta_a$,.
#
#
# __Diámetro, $D_{air}$, de la Línea Central del Orificio de Vapor__
#
# Los orificios de vapor están dispuestos en un círculo de diámetro Dair. Si el espacio mínimo entre orificios adyacentes es de 1 mm, el diámetro del círculo que contiene n orificios está alrededor de la circunferencia, entonces:
#
# $$D_{air}=\frac{n (d_2+1)}{\pi}$$
#
#
# __Diámetro Anular, $D_{mix}$ del Orificio de Mezcla__
#
# Desde la geometría , se obtiene:
#
# $$D_{mix}=D_{air}+2(l_1+l_2+l_3)sin(\frac{\theta_a}{2})$$
#
# La relación entre la longitud del orificio de vapor, 12, y el diámetro del orificio, d2, se puede elegir en el rango de 2-10 dependiendo del diseño mecánico y la conveniencia del proceso de fabricación.
#
#
# __Diámetro Medio Ponderado de las Gotas__
#
# Se puede usar la siguiente relación empírica para la estimación de los tamaños de las gotas
#
# $$d_{drop}=\frac{200 \nu^{0.5} m ^{0.1} (1+ \frac{1}{1})^{0.5} d_3^{0.1} \sigma_{oil}^{0.2}}{\rho_{steam}^{0.3} W_r}$$
#
# donde:
#
# - $ν_{oil}$: viscosidad del aceite, centistokes (Cst)
# - $m_{oil}$: tasa de flujo de aceite por orificio, g/s
# - $q$: tasa de consumo de vapor, g vapor/kg aceite
# - $d_3$: diámetro del orificio de mezcla, cm
# - $\sigma_{oil}$: tensión superficial del aceite, dyn/cm
# - $ρ_{steam}$: densidad del vapor a la presión del vapor en el orificio de mezcla, g/cm³
# - $w_{cr}$: velocidad relativa entre el aceite y el medio atomizador (para vapor, se puede aproximar como $w_cr = k \cdot (P_steam - P_fsteam)$ m/s)
# - $k$ = 3.33 para vapor sobrecalentado, 3.22 para vapor saturado, 3.38 para aire comprimido
# - $P_{steam}$: presión del medio atomizador, Pa
# - $ν_{steam}$: volumen específico del vapor, m³/kg

# %% [markdown]
# __Bibliografia__
#
# Basu, Prabir & Kefa, Cen & Jestin, Louis. (2000). Boilers and Burners : Design and Theory / P. Basu, C. Kefa, L. Jestin.. 10.1007/978-1-4612-1250-8.
#
# Baukal Jr., C.E. (Ed.). (2013). The John Zink Hamworthy Combustion Handbook: Volume 1 - Fundamentals (2nd ed.). CRC Press. https://doi.org/10.1201/b12975
#
# Rayaprolu, K. (2009). Boilers for Power and Process (1st ed.). CRC Press. https://doi.org/10.1201/EBK1420075366
#
# Rayaprolu, K. (2013). Boilers: A Practical Reference (1st ed.). CRC Press. https://doi.org/10.1201/b12977.

# %% [markdown]
# ##6. Combustibles gaseosos
#
# Los combustibles gaseosos son aquellos que están en estado gaseoso a temperatura ambiente. Ejemplos de combustibles gaseosos son el gas natural y el propano.
#
# ###6.1 Gas natural
#
# El gas natural es un combustible gaseoso que se compone principalmente de metano. Se utiliza principalmente para la calefacción y la generación de electricidad.
#
# ![gas](https://upload.wikimedia.org/wikipedia/commons/0/06/Gas-natural.jpg)
#
# ###6.2 Propano
#
# El propano es un combustible gaseoso que se obtiene de la destilación del petróleo. Se utiliza principalmente para la calefacción y la cocción de alimentos.
#
# ![propane](https://upload.wikimedia.org/wikipedia/commons/f/fe/Propane_tank_20lb.jpg)

# %% [markdown]
# ## 7. Sistemas de Combustión de Gases
#
# Un método común para clasificar quemadores es según cómo se mezclan el combustible y el oxidante:
# * Quemadores atmosféricos.
# * En los quemadores premezclados el combustible y el oxidante se mezclan completamente antes de que comience la combustión.
# * Los quemadores de pared radiante suelen ser del tipo premezclado. Estos quemadores a menudo producen llamas más cortas e intensas en comparación con las llamas de difusión. Este tipo de llama se prefiere en, por ejemplo, hornos de craqueo de etileno porque los quemadores de pared radiante están cerca de los tubos de proceso, lo que puede generar regiones de alta temperatura en la llama, lo que lleva a un calentamiento no uniforme de la carga y mayores emisiones de NOx.

# %% [markdown]
# ### 7.1 Quemadores Atmosféricos

# %% [markdown]
# En los quemadores atmosféricos, el aire utilizado para la combustión es inducido en el quemador por el tiro negativo producido en el quemador. Un dibujo se muestra en la figura. En este tipo de quemador, la caída de presión y la altura de la chimenea del quemador son críticas para producir suficiente succión para inducir suficiente aire de combustión en los quemadores. Este tipo de quemador se utiliza comúnmente en las industrias química y petroquímica en calentadores de fluidos.
#
# La principal consecuencia del tipo de tiro en la transferencia de calor es que las llamas de quemadores atmosféricos suelen ser más largas que las llamas de tiro forzado, lo que hace que el flujo de calor de la llama se distribuya sobre una distancia más larga y la temperatura máxima en la llama sea generalmente más baja. Es importante tener en cuenta que en aplicaciones de tiro forzado, los quemadores suelen estar diseñados para funcionar como quemadores de tiro natural en caso de que haya algún problema con el ventilador de aire de combustión (por ejemplo, una falla de energía). En general, la capacidad de calor se reduce cuando los quemadores de tiro forzado operan en condiciones de tiro natural.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Baukal Jr., C.E. (Ed.). (2013)

# %% [markdown]
# ### 7.2 Quemadores de Difusión de Llama

# %% [markdown]
# En las llamas de difusión-mezcladas, el combustible y el oxidante están separados y sin mezclar antes de que comience la combustión, que comienza donde la mezcla de oxidante/combustible está dentro del rango de inflamabilidad. Un ejemplo de una llama de difusión es una vela. Un quemador de gas de difusión-mezcla se muestra esquemáticamente. A veces se le conoce como quemador "sin mezcla" o "gas crudo" porque el gas combustible sale del quemador esencialmente como gas crudo sin mezclar con aire. Los quemadores de difusión suelen tener llamas más largas que los quemadores premezclados, un punto caliente de menor temperatura y una distribución de flujo de calor más uniforme.

# %% [markdown]
# __Diagrama de flama de difusión__
#
# ![image.png](data:image/png;base64,...)
#
# Baukal Jr., C.E. (Ed.). (2013)

# %% [markdown]
# ### 7.3 Quemadores de Chorro de Aire

# %% [markdown]
# El aire escalonado es una técnica utilizada para reducir las emisiones de NOx en la combustión de combustibles. Consiste en quemar el combustible bajo condiciones locales sustancialmente diferentes de las estequiométricas, como enriquecido o empobrecido, de manera que la combustión no genere temperaturas altas propicias para la formación de NOx.
#
# En equipos de combustión convencionales, el combustible suele quemarse después de agregar solo una cantidad parcial de aire, muy por debajo de la cantidad estequiométrica. El resto del aire se añade después de que los productos de la combustión pierdan una cantidad sustancial de calor. Como resultado, la sección inicial rica de la llama y la parte final empobrecida de la llama se encuentran a temperaturas más bajas debido a la transferencia de calor previa desde la sección rica. Esto reduce la temperatura máxima de la llama en toda la zona de la llama y disminuye la formación de NOx térmico.
#
# El aire escalonado por sí solo puede reducir típicamente el NOx en un 20% - 60%. Cualquier reducción más profunda puede volverse problemática y no confiable. Los quemadores con aire escalonado suelen ser pobres candidatos para la operación con recirculación de gases de escape (FGR) ya que la combinación de condiciones ricas en combustible con reducido oxígeno resulta en una inflamabilidad marginal para la mayoría de los combustibles hidrocarburos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Baukal Jr., C.E. (Ed.). (2013)

# %% [markdown]
# ### 7.4 Sistemas (Cámaras) de Premezcla

# %% [markdown]
# También es posible tener quemadores parcialmente premezclados, mostrados esquemáticamente en la figura 1.45, donde una fracción del combustible se mezcla con el oxidante. La premezcla parcial se hace a menudo por razones de estabilidad y seguridad, ya que no solo ayuda a anclar la llama, sino que también reduce la posibilidad de retroceso (ver Capítulo 1 en Volumen 2), lo cual es a veces un problema en quemadores totalmente premezclados. Este tipo de quemador a menudo tiene una longitud de llama, temperatura y distribución de flujo de calor que se encuentra entre las llamas totalmente premezcladas y las de difusión.
#
# Otra clasificación de quemadores basada en la mezcla se conoce como "estaging" o etapas de aire y/o etapas de combustible. Un quemador de aire estagado se muestra esquemáticamente en la figura 1.46. Se utilizan inyectores secundarios y a veces terciarios en el quemador para inyectar una porción del combustible y/o del aire en la llama, aguas abajo de la base de la llama. El "estaging" se hace a menudo para reducir las emisiones de NOx y producir llamas más largas. Estas llamas más largas suelen tener una temperatura de punta más baja y una distribución de flujo de calor más uniforme que las llamas no estagadas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Baukal Jr., C.E. (Ed.). (2013)

# %% [markdown]
# ### 7.5 Combustibles No Fósiles
#
# __Hidrógeno__
#
#     Fuente: Puede producirse por reformado de gas natural (con emisiones de CO₂) o mediante electrólisis del agua (energía eléctrica separa H₂ y O₂).
#     Ventajas: Su combustión produce principalmente vapor de agua, sin emisiones de CO₂ en el uso final.
#     Desafíos: Almacenamiento y transporte complicados (requiere alta presión o muy baja temperatura), producción aún costosa si se quiere bajo o cero carbono.
#
# ![propane](https://upload.wikimedia.org/wikipedia/commons/8/83/Hydrogen_discharge_tube.jpg)
#
# __Biogás__
#
# Surge de la descomposición anaeróbica de residuos orgánicos (agroindustriales, vertederos, etc.).
#
# ![propane](https://upload.wikimedia.org/wikipedia/commons/9/92/Biogas_flame_%285363885380%29.jpg)
#
# Residuos sólidos urbanos (RSU) y biomasa: Se pueden procesar para obtener combustibles sólidos, líquidos o gaseosos.
#
#
# __Syngas (gas de síntesis)__
#
# Mezcla de H₂ y CO procedente de gasificación de carbón, biomasa o residuos.

# %% [markdown]
# __Bibliografia__
#
# Basu, Prabir & Kefa, Cen & Jestin, Louis. (2000). Boilers and Burners : Design and Theory / P. Basu, C. Kefa, L. Jestin.. 10.1007/978-1-4612-1250-8.
#
# Baukal Jr., C.E. (Ed.). (2013). The John Zink Hamworthy Combustion Handbook: Volume 1 - Fundamentals (2nd ed.). CRC Press. https://doi.org/10.1201/b12975
#
# Rayaprolu, K. (2009). Boilers for Power and Process (1st ed.). CRC Press. https://doi.org/10.1201/EBK1420075366
#
# Rayaprolu, K. (2013). Boilers: A Practical Reference (1st ed.). CRC Press. https://doi.org/10.1201/b12977.
